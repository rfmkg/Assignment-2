# %%
import pandas as pd
from IPython.display import display

df = pd.read_csv("Student_Mental_Health_Academic_Pressure_2025.csv")

shape_df = pd.DataFrame({
    "Rows": [df.shape[0]],
    "Columns": [df.shape[1]]
})
display(shape_df)

first_five_df = df.head(5)
display(first_five_df)

first_five_df.to_excel("student_first_5_records.xlsx", index=False)

columns_df = pd.DataFrame({
    "Column Name": df.columns
})
display(columns_df)

dtypes_df = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": df.dtypes.values
})
display(dtypes_df)
# Out:
#    Rows  Columns
# 0    33        8
#          Timestamp Age Group   Gender\n     Current Education Level    \
# 0  12/13/2025 6:18     15–18       Female                     College
# 1  12/13/2025 6:24     15–18         Male                     College
# 2  12/13/2025 6:29     15–18       Female                  University
# 3  12/13/2025 7:36       27+         Male                       Other
# 4  12/13/2025 8:01     15–18       Female                     College
#
#      How much academic pressure do you feel?    \
# 0                                            4
# 1                                            4
# 2                                            3
# 3                                            1
# 4                                            2
#
#    How often do you feel stressed due to studies?  \
# 0                                       Sometimes
# 1                                           Often
# 2                                       Sometimes
# 3                                          Always
# 4                                       Sometimes
#
#     How many hours do you sleep on average per night?    \
# 0                                                7–8
# 1                                                5–6
# 2                                                7–8
# 3                                                7–8
# 4                                                5–6
#
#     What is the main cause of your academic stress?
# 0                      1 .Exam and grades pressure
# 1                          Exams and Grades Pressure
# 2                              financial conditions
# 3                                             Other
# 4                                  Prefer not to say
#                                          Column Name
# 0                                          Timestamp
# 1                                          Age Group
# 2                                         Gender\n
# 3                          Current Education Level
# 4          How much academic pressure do you feel?
# 5     How often do you feel stressed due to studies?
# 6    How many hours do you sleep on average per n...
# 7    What is the main cause of your academic stre...
#                                          Column Name Data Type
# 0                                          Timestamp    object
# 1                                          Age Group    object
# 2                                         Gender\n      object
# 3                          Current Education Level      object
# 4          How much academic pressure do you feel?       int64
# 5     How often do you feel stressed due to studies?    object
# 6    How many hours do you sleep on average per n...    object
# 7    What is the main cause of your academic stre...    object
